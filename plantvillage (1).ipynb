# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
train_dir = "path_to_train_folder"
val_dir = "path_to_val_folder"
train_datagen = ImageDataGenerator(
    rescale=1./255,
    zoom_range=0.2,
    shear_range=0.2,
    horizontal_flip=True
)
val_datagen = ImageDataGenerator(rescale=1./255)

# %%
import tensorflow as tf

train_ds = tf.keras.utils.image_dataset_from_directory(
    r"C:\Users\afrin\Downloads\Plantvillage\PlantVillage\train",
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=(224, 224),
    batch_size=32
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    r"C:\Users\afrin\Downloads\Plantvillage\PlantVillage\train",
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=(224, 224),
    batch_size=32
)
# Out:
# Found 43444 files belonging to 38 classes.
# Using 34756 files for training.
# Found 43444 files belonging to 38 classes.
# Using 8688 files for validation.

# %%
val_data = tf.keras.preprocessing.image_dataset_from_directory(
    r"C:\Users\afrin\Downloads\Plantvillage\PlantVillage\val",
    image_size=(224, 224),
    batch_size=32,
    label_mode='categorical',
    shuffle=False          
)
# Out:
# Found 10861 files belonging to 38 classes.

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(224,224,3)),
    tf.keras.layers.MaxPooling2D(2,2),

    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),

    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),

    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(38, activation='softmax')  # 38 classes
])

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
train_data = tf.keras.preprocessing.image_dataset_from_directory(
    r"C:\Users\afrin\Downloads\Plantvillage\PlantVillage\train",
    image_size=(224, 224),
    batch_size=32
)

val_data = tf.keras.preprocessing.image_dataset_from_directory(
    r"C:\Users\afrin\Downloads\Plantvillage\PlantVillage\val",
    image_size=(224, 224),
    batch_size=32
)

history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=10
)
# Out:
# Found 43444 files belonging to 38 classes.
# Found 10861 files belonging to 38 classes.
# Epoch 1/10
# 1358/1358 [==============================] - 4886s 4s/step - loss: 2.4795 - accuracy: 0.5107 - val_loss: 1.1160 - val_accuracy: 0.6690
# Epoch 2/10
# 1358/1358 [==============================] - 25004s 18s/step - loss: 0.7132 - accuracy: 0.7855 - val_loss: 0.7352 - val_accuracy: 0.7884
# Epoch 3/10
# 1358/1358 [==============================] - 3065s 2s/step - loss: 0.3574 - accuracy: 0.8877 - val_loss: 0.9334 - val_accuracy: 0.7727
# Epoch 4/10
# 1358/1358 [==============================] - 2973s 2s/step - loss: 0.2450 - accuracy: 0.9235 - val_loss: 0.9979 - val_accuracy: 0.7630
# Epoch 5/10
# 1358/1358 [==============================] - 3385s 2s/step - loss: 0.2111 - accuracy: 0.9353 - val_loss: 1.0119 - val_accuracy: 0.7936
# Epoch 6/10
# 1358/1358 [==============================] - 3117s 2s/step - loss: 0.1428 - accuracy: 0.9560 - val_loss: 1.2208 - val_accuracy: 0.7954
# Epoch 7/10
# 1358/1358 [==============================] - 3294s 2s/step - loss: 0.1533 - accuracy: 0.9558 - val_loss: 1.1470 - val_accuracy: 0.8033
# Epoch 8/10
# 1358/1358 [==============================] - 3335s 2s/step - loss: 0.1207 - accuracy: 0.9659 - val_loss: 1.0340 - val_accuracy: 0.8124
# Epoch 9/10
# 1358/1358 [==============================] - 5215s 4s/step - loss: 0.1210 - accuracy: 0.9668 - val_loss: 1.2758 - val_accuracy: 0.7990
# Epoch 10/10
# 1358/1358 [==============================] - 3402s 3s/step - loss: 0.1364 - accuracy: 0.9648 - val_loss: 1.1271 - val_accuracy: 0.8162

# %%
plt.plot(history.history['accuracy'],
         label='train accuracy')
plt.plot(history.history['val_accuracy'],
         label='val accuracy')
plt.legend()
plt.show()

# %%
base_model = tf.keras.applications.MobileNetV2(
    input_shape=(224,224,3),
    include_top=False,
    weights='imagenet'
)

# %%
cd Plant_village-Project
# Out:
# [WinError 2] The system cannot find the file specified: 'Plant_village-Project'
# C:\Users\afrin
# C:\Users\afrin\AppData\Roaming\Python\Python310\site-packages\IPython\core\magics\osm.py:393: UserWarning: This is now an optional IPython functionality, using bookmarks requires you to install the `pickleshare` library.
#   bkms = self.shell.db.get('bookmarks', {})

# %%
# !git init
# Out:
# Reinitialized existing Git repository in C:/Users/afrin/.git/

# %%
model.save("plant_model.keras")

# %%
from tensorflow.keras.models import load_model

# %%
model = load_model("plant_model.keras")

# %%
loss, acc = model.evaluate(val_data)
print("Accuracy:", acc)
# Out:
# 340/340 [==============================] - 224s 657ms/step - loss: 1.1271 - accuracy: 0.8162
# Accuracy: 0.8162232041358948

# %%
import os
os.listdir("C:/Users/afrin")
# Out:
# ['-1.14-windows.xml',
#  '.anaconda',
#  '.bash_history',
#  '.conda',
#  '.continuum',
#  '.git',
#  '.gitconfig',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.keras',
#  '.lesshst',
#  '.matplotlib',
#  '.python_history',
#  '.vscode',
#  'anaconda3_new',
#  'AppData',
#  'apple dataset.ipynb',
#  'Application Data',
#  'Contacts',
#  'Cookies',
#  'Demo.ipynb',
#  'Documents',
#  'Downloads',
#  'Favorites',
#  'Kisanmitra dataset .ipynb',
#  'Kisanmitra training.ipynb',
#  'kisan_mitra_model.h5',
#  'Links',
#  'Local Settings',
#  'model.h5',
#  'Music',
#  'My Documents',
#  'my_array.npy',
#  'my_array_npy.npy',
#  'Name. Muhamad Danish Ahmad.txt',
#  'NetHood',
#  'New folder (2)',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{1eb38290-7b1e-11ef-b695-4438e86488b7}.TM.blf',
#  'NTUSER.DAT{1eb38290-7b1e-11ef-b695-4438e86488b7}.TMContainer00000000000000000001.regtrans-ms',
#  'NTUSER.DAT{1eb38290-7b1e-11ef-b695-4438e86488b7}.TMContainer00000000000000000002.regtrans-ms',
#  'ntuser.ini',
#  'numpy_tutorial.ipynb',
#  'OneDrive',
#  'plant disease dataset.ipynb',
#  'Plant-village-',
#  'plantvillage.ipynb',
#  'plant_model.keras',
#  'prac tf.ipynb',
#  'PrintHood',
#  'Recent',
#  'Saved Games',
#  'Searches',
#  'SendTo',
#  'Start Menu',
#  'Templates',
#  'Untitled.ipynb',
#  'untitled.txt',
#  'Untitled1.ipynb',
#  'Untitled2.ipynb',
#  'Videos']

# %%
train_dir = "C:/Users/afrin/Downloads/Plantvillage/PlantVillage/train"
val_dir = "C:/Users/afrin/Downloads/Plantvillage/PlantVillage/val"

# %%
base_model = tf.keras.applications.MobileNetV2(
    input_shape=(224,224,3),
    include_top=False,
    weights='imagenet'
)

base_model.trainable = False

model = tf.keras.Sequential([
    base_model,
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(38, activation='softmax')
])

# %%
img = image.load_img(r"C:\Users\afrin\Downloads\Plantvillage\PlantVillage\test",
                     target_size=(224,224))
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 img = image.load_img(r"C:\Users\afrin\Downloads\Plantvillage\PlantVillage\test",
#       2                      target_size=(224,224))
#
# File ~\AppData\Roaming\Python\Python310\site-packages\keras\utils\image_utils.py:422, in load_img(path, grayscale, color_mode, target_size, interpolation, keep_aspect_ratio)
#     420     if isinstance(path, pathlib.Path):
#     421         path = str(path.resolve())
# --> 422     with open(path, "rb") as f:
#     423         img = pil_image.open(io.BytesIO(f.read()))
#     424 else:
#
# PermissionError: [Errno 13] Permission denied: 'C:\\Users\\afrin\\Downloads\\Plantvillage\\PlantVillage\\test'

# %%
from tensorflow.keras.preprocessing import image
import numpy as np

img = image.load_img(
    r"C:\Users\afrin\Downloads\Plantvillage\PlantVillage\test",
    target_size=(224,224)
)

img_array = image.img_to_array(img)/255
img_array = np.expand_dims(img_array, axis=0)

prediction = model.predict(img_array)
print(prediction)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[56], line 4
#       1 from tensorflow.keras.preprocessing import image
#       2 import numpy as np
# ----> 4 img = image.load_img(
#       5     r"C:\Users\afrin\Downloads\Plantvillage\PlantVillage\test",
#       6     target_size=(224,224)
#       7 )
#       9 img_array = image.img_to_array(img)/255
#      10 img_array = np.expand_dims(img_array, axis=0)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\keras\utils\image_utils.py:422, in load_img(path, grayscale, color_mode, target_size, interpolation, keep_aspect_ratio)
#     420     if isinstance(path, pathlib.Path):
#     421         path = str(path.resolve())
# --> 422     with open(path, "rb") as f:
#     423         img = pil_image.open(io.BytesIO(f.read()))
#     424 else:
#
# PermissionError: [Errno 13] Permission denied: 'C:\\Users\\afrin\\Downloads\\Plantvillage\\PlantVillage\\test'
